# %% [markdown]
# ### Importamos librerías y soportes

# %%
import pandas as pd
from IPython.display import display
import json
import sys
import random
import warnings
warnings.simplefilter(action='ignore')


sys.path.append("../")
from src import soporte_funciones as sf #Archivo .py donde encontraremos todas nuestras funciones.
pd.set_option('display.max_columns', None) #Fuerza al notebook a mostrar todas las columnas de un DF.

# %%
#calendario_lgw = sf.calendario_precios_vuelos("MAD","LGW","2024-10-19")
#calendario_lgw.to_csv("../datos/calendario_londres.csv")
# Out:
#          Fecha Tipo de Precio  Precio Fecha Captura
# 0   2024-10-19           Alto  180.15    2024-10-19
# 1   2024-10-20           Alto   98.45    2024-10-19
# 2   2024-10-21           Alto   81.00    2024-10-19
# 3   2024-10-22          Medio   71.93    2024-10-19
# 4   2024-10-23          Medio   72.01    2024-10-19
# ..         ...            ...     ...           ...
# 355 2025-10-09           Bajo   32.90    2024-10-19
# 356 2025-10-10          Medio   35.98    2024-10-19
# 357 2025-10-11          Medio   35.67    2024-10-19
# 358 2025-10-12           Bajo   33.25    2024-10-19
# 359 2025-10-13          Medio   35.51    2024-10-19
#
# [360 rows x 4 columns]

# %%
calendario_muc = sf.calendario_precios_vuelos("MAD","MUC","2024-10-19")
calendario_muc.to_csv("../datos/calendario_munich.csv")
# Out:
#          Fecha Tipo de Precio  Precio Fecha Captura
# 0   2024-10-19           Alto  189.27    2024-10-19
# 1   2024-10-20           Alto  154.00    2024-10-19
# 2   2024-10-21           Alto  150.53    2024-10-19
# 3   2024-10-22           Alto  131.00    2024-10-19
# 4   2024-10-23           Alto  120.00    2024-10-19
# ..         ...            ...     ...           ...
# 282 2025-09-21          Medio   96.80    2024-10-19
# 283 2025-09-25          Medio   77.80    2024-10-19
# 284 2025-09-26          Medio  106.11    2024-10-19
# 285 2025-09-30          Medio   77.80    2024-10-19
# 286 2025-10-02          Medio   78.01    2024-10-19
#
# [287 rows x 4 columns]

# %%
#vuelos_munich = sf.mostrar_destinos_vuelos()
#vuelos_munich.to_csv("../datos/vuelos_munich.csv")
# Out:
# Los destinos disponibles son:
# 1. Londres
# 2. Munich
#    Fecha Salida Hora Salida Fecha Llegada Hora Llegada  Origen Destino  \
# 0    2024-11-15    07:05:00    2024-11-15     09:45:00  Madrid  Munich
# 1    2024-11-18    19:05:00    2024-11-18     21:50:00  Munich  Madrid
# 2    2024-11-15    15:00:00    2024-11-15     17:40:00  Madrid  Munich
# 3    2024-11-18    19:05:00    2024-11-18     21:50:00  Munich  Madrid
# 4    2024-11-15    08:50:00    2024-11-15     11:30:00  Madrid  Munich
# 5    2024-11-18    12:10:00    2024-11-18     15:00:00  Munich  Madrid
# 6    2024-11-15    16:00:00    2024-11-15     18:35:00  Madrid  Munich
# 7    2024-11-18    12:10:00    2024-11-18     15:00:00  Munich  Madrid
# 8    2024-11-15    20:00:00    2024-11-15     22:40:00  Madrid  Munich
# 9    2024-11-18    12:10:00    2024-11-18     15:00:00  Munich  Madrid
# 10   2024-11-15    15:00:00    2024-11-15     17:40:00  Madrid  Munich
# ...

# %%
#vuelos_londres = sf.mostrar_destinos_vuelos()
#vuelos_londres.to_csv("../datos/vuelos_londres.csv")
# Out:
# Los destinos disponibles son:
# 1. Londres
# 2. Munich
#    Fecha Salida Hora Salida Fecha Llegada Hora Llegada          Origen  \
# 0    2024-11-15    08:55:00    2024-11-15     10:15:00          Madrid
# 1    2024-11-18    15:20:00    2024-11-18     22:50:00  London Gatwick
# 2    2024-11-15    17:30:00    2024-11-15     18:50:00          Madrid
# 3    2024-11-18    15:20:00    2024-11-18     22:50:00  London Gatwick
# 4    2024-11-15    08:55:00    2024-11-15     10:15:00          Madrid
# 5    2024-11-18    14:55:00    2024-11-18     22:50:00  London Gatwick
# 6    2024-11-15    17:30:00    2024-11-15     18:50:00          Madrid
# 7    2024-11-18    14:55:00    2024-11-18     22:50:00  London Gatwick
# 8    2024-11-15    12:50:00    2024-11-15     20:20:00          Madrid
# 9    2024-11-18    14:55:00    2024-11-18     22:50:00  London Gatwick
# 10   2024-11-15    12:50:00    2024-11-15     20:20:00          Madrid
# ...

# %%
hoteles_londres = sf.mostrar_destinos_hoteles()
hoteles_londres.to_csv("../datos/hoteles_londres.csv")
# Out:
# Los destinos disponibles son:
# 1. Londres
# 2. Munich
# Te mostramos los hoteles disponibles en Londres con entrada el 2024-11-15 y salida el 2024-11-18, con precio total entre 400 y 600.
#                                                Nombre    Entrada     Salida  \
# 0   Holiday Inn Express London-Hammersmith, an IHG... 2024-11-15 2024-11-18
# 1   Holiday Inn Express London - Wandsworth, an IH... 2024-11-15 2024-11-18
# 2                               Hilton London Olympia 2024-11-15 2024-11-18
# 3                         citizenM Southwark Bankside 2024-11-15 2024-11-18
# 4                                          City Rooms 2024-11-15 2024-11-18
# 5                                 The Tudor Inn Hotel 2024-11-15 2024-11-18
# 6                  Hampton By Hilton London Docklands 2024-11-15 2024-11-18
# 7                            Novotel London Greenwich 2024-11-15 2024-11-18
# 8                              The Corner London City 2024-11-15 2024-11-18
# ...

# %%
hoteles_munich = sf.mostrar_destinos_hoteles()
hoteles_munich.to_csv("../datos/hoteles_munich.csv")
# Out:
# Los destinos disponibles son:
# 1. Londres
# 2. Munich
# Te mostramos los hoteles disponibles en Munich con entrada el 2024-11-15 y salida el 2024-11-18, con precio total entre 400 y 600.
#                                                Nombre    Entrada     Salida  \
# 0                        King's Hotel Center Superior 2024-11-15 2024-11-18
# 1               Ramada Encore by Wyndham Munich Messe 2024-11-15 2024-11-18
# 2        Holiday Inn Munich City Centre, an IHG Hotel 2024-11-15 2024-11-18
# 3                  Leonardo Hotel & Residenz Muenchen 2024-11-15 2024-11-18
# 4    Holiday Inn Express - MUNICH NORTH, an IHG Hotel 2024-11-15 2024-11-18
# 5                               Maritim Hotel München 2024-11-15 2024-11-18
# 6                                        Hotel Seibel 2024-11-15 2024-11-18
# 7                           B&B Hotel München-Moosach 2024-11-15 2024-11-18
# 8                       Timehouse Serviced Apartments 2024-11-15 2024-11-18
# ...

# %%
actividades_londres = sf.mostrar_destinos_actividades()
actividades_londres.to_csv("../datos/actividades_londres.csv")
# Out:
# Los destinos disponibles son:
# 1. Londres
# 2. Munich
# Te mostramos las actividades disponibles en Londres
# Error al aceptar cookies: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#__layout > div > div.cookie-banner.cookie-banner-desktop.cookie-banner--v2 > div.cookie-banner__btns-container--v2 > button:nth-child(2)"}
#   (Session info: chrome=129.0.6668.101); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000101344500 cxxbridge1$str$ptr + 1917112
# 1   chromedriver                        0x000000010133c890 cxxbridge1$str$ptr + 1885256
# 2   chromedriver                        0x0000000100f4c538 cxxbridge1$string$len + 89424
# 3   chromedriver                        0x0000000100f90878 cxxbridge1$string$len + 368784
# ...

# %%
actividades_munich = sf.mostrar_destinos_actividades()
actividades_munich.to_csv("../datos/actividades_munich.csv")
# Out:
# Los destinos disponibles son:
# 1. Londres
# 2. Munich
# Te mostramos las actividades disponibles en Múnich
# Error al aceptar cookies: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#__layout > div > div.cookie-banner.cookie-banner-desktop.cookie-banner--v2 > div.cookie-banner__btns-container--v2 > button:nth-child(2)"}
#   (Session info: chrome=129.0.6668.101); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102724500 cxxbridge1$str$ptr + 1917112
# 1   chromedriver                        0x000000010271c890 cxxbridge1$str$ptr + 1885256
# 2   chromedriver                        0x000000010232c538 cxxbridge1$string$len + 89424
# 3   chromedriver                        0x0000000102370878 cxxbridge1$string$len + 368784
# ...
